# %% [markdown]
# ### ConfigBox

# %%
import yaml

yaml_file_path = "test.yaml"

# Open yaml file and load it's content

with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)

# %%
data
# Out:
# {'name': 'abc', 'email': 'abc@gmail.com'}

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
data["name"]
# Out:
# 'abc'

# %%
data.values()
# Out:
# dict_values(['abc', 'abc@gmail.com'])

# %%
data.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
from box import ConfigBox

config_data = ConfigBox(data)

config_data.name
# Out:
# 'abc'

# %%
config_data.email
# Out:
# 'abc@gmail.com'

# %% [markdown]
# ### ensure_annotations

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(x=2,y="2")
# Out:
# '22'

# %%
from ensure import ensure_annotations


@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(2,"4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 get_product(2,"4")
#
# File c:\ML\MLOPs Production Ready Deep Learning Project\.venv\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000002013D2C7640> does not match annotation type <class 'int'>

# %% [markdown]
# ### Download data from googledrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1OxBDwv_zVBXA-SQSFHs1GlC_wc-icomL/view?usp=drive_link"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1OxBDwv_zVBXA-SQSFHs1GlC_wc-icomL',
#  'view?usp=drive_link']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1OxBDwv_zVBXA-SQSFHs1GlC_wc-icomL'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1OxBDwv_zVBXA-SQSFHs1GlC_wc-icomL
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1OxBDwv_zVBXA-SQSFHs1GlC_wc-icomL&confirm=t&uuid=bc0596e1-7bbd-4b62-b26b-98dd2a25d76d
# To: c:\ML\MLOPs Production Ready Deep Learning Project\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:02<00:00, 17.8MB/s]
# 'Chest-CT-Scan-data.zip'

# %%
##
